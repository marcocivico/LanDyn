# %% [markdown]
# <a href="https://colab.research.google.com/github/marcocivico/LanDyn/blob/master/LSTM_JaneAusten.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import random
import io

# %%
text=[]
with open("jane_austen_novels_UTF.txt", "r", encoding="UTF-8") as file:
    text = file.read()

print("Corpus length:", len(text))

chars = sorted(list(set(text)))
print("Total chars:", len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i : i + maxlen])
    next_chars.append(text[i + maxlen])
print("Number of sequences:", len(sentences))

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=bool)
y = np.zeros((len(sentences), len(chars)), dtype=bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Corpus length: 4305272
# Total chars: 79
# Number of sequences: 1435078

# %%
# EDA: Generating WordCloud to visualize
# the text
wordcloud = WordCloud(max_font_size=50,
                      max_words=100,
                      background_color="black").generate(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-dc1521527cb8> in <module>
#       1 # EDA: Generating WordCloud to visualize
#       2 # the text
# ----> 3 wordcloud = WordCloud(max_font_size=50,
#       4                       max_words=100,
#       5                       background_color="black").generate(text)
#
# NameError: name 'WordCloud' is not defined

# %%
# Plotting the WordCloud
plt.figure(figsize=(8, 4))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig("WordCloud.png")
plt.show()

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(maxlen, len(chars))),
        layers.LSTM(128),
        layers.Dense(len(chars), activation="softmax"),
    ]
)
optimizer = keras.optimizers.RMSprop(learning_rate=0.001)
model.compile(loss="categorical_crossentropy", optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
epochs = 40
batch_size = 128

for epoch in range(epochs):
    model.fit(x, y, batch_size=batch_size, epochs=1)
    print()
    print("Generating text after epoch: %d" % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print("...Diversity:", diversity)

        generated = ""
        sentence = text[start_index : start_index + maxlen]
        print('...Generating with seed: "' + sentence + '"')

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.0
            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
            sentence = sentence[1:] + next_char
            generated += next_char

        print("...Generated: ", generated)
        print()
# Out:
# 11212/11212 [==============================] - 80s 7ms/step - loss: 1.8827
#
# Generating text after epoch: 0
# ...Diversity: 0.2
# ...Generating with seed: "y was convinced of his father's believin"
# ...Generated:  g to the rease to be all the forther at the some as she was a sister the come to see the complation to the look and any the was as so man the more to some have been a such a some all the compors as the comporion of the parting to the come to be allowed the streing to her for the thought to the some to be so dear and person and such a some to be a some to be allowing to be allowing to the reasing t
#
# ...Diversity: 0.5
# ...Generating with seed: "y was convinced of his father's believin"
# ...Generated:  g by in it all to all the one of his compertion and again to the realons would be amore of the consent to not. I conlended before the compors compless to farthing her consintance of the looks as sich was the composion of her to the exert and astence of his propess, and she the prepent was so not to have been satied and the forther it conded to this more the mort houres and a shore that he had not
#
# ...Diversity: 1.0
# ...Generating with seed: "y was convinced of his father's believin"
# ...Generated:  g un lookins of correst, she could not withen her other, and coustes in atttirutations astingernged." -rank et was, that whith fell thit, it said a momeftly alith for the goud it with anote! Eus" propost a all eeving acquitience to my of this wist moments. It was eveing the monjegts. The firsp, Edonihince, whech; when the feeswer the lade father, but the crillend, vear had been such a yourgall. Mo
#
# ...Diversity: 1.2
# ...Generating with seed: "y was convinced of his father's believin"
# ...Generated:  g to hirsely. -he had ils Cattaniond were willln-que toreing to speef ginate know whither, Mrs.. Cho most's morote. But that wo doment ans regret wains. Wy My. Crupstinly desirste my begtaicted," sus lesturiage, un every. Miss Lurcye lestarachtaged the nectuse theme you." chewmeit, was nothed. She Ivench a seituly, bus alpeatiness, a suchising-sssing more;," carnet wopld ". ken Hyorderled now ande
#
# 11212/11212 [==============================] - 74s 7ms/step - loss: 1.4677
#
# Generating text after epoch: 1
# ...Diversity: 0.2
# ...Generating with seed: "ooth gravel winding round a plantation, "
# ...Generated:  and the world and the subject of the more of the party of the consentance of the party of the most belies of the partery the consention of the subject of the party of the consented to be a little them a great seemed to be a sent and a most belies of the country seemed them all the present of the douse and the great seat of the subject of the company the company of the consedutions of the consented
#
# ...Diversity: 0.5
# ...Generating with seed: "ooth gravel winding round a plantation, "
# ...Generated:  and first the command the obsed the doubt and the something such a play of their will be the belt to be an heart to be there became them and at a little them were the haming to the family at least of the country speed him to see it was all the sister of the sisters as it was a last of any constand her to see state of the particulars and every thing and best particulary the country the house of the
#
# ...Diversity: 1.0
# ...Generating with seed: "ooth gravel winding round a plantation, "
# ...Generated:  and you what she mean soon miles on of princince whea mith it was not to the dones; but ceplaces you sey his seived again of her sisear of the loes, the misupofied, and weak on to sobrean which had been it any distress and as seemed addidered of other dwelvesh by old awasting will much might not entered of her wenmoy will all the off mur. I fot see" must be as inthing at all. We could, or of the w
#
# ...Diversity: 1.2
# ...Generating with seed: "ooth gravel winding round a plantation, "
# ...Generated:  the , and the yaugh's kivelly connequencen, and now I amfate they. In when being it hus both, which them should not reakbarmed gue them weph as off. "Hen. Mrs. Cushwas to acquainued her comtage accosited as you tond an veess. Lopedan was side. It way for a much aftidal persaprions, when longly opery on its them ouths than made her regarancituly bowing nexe-in sefired to really equally distincturat
#
# 11212/11212 [==============================] - 74s 7ms/step - loss: 1.3568
#
# Generating text after epoch: 2
# ...Diversity: 0.2
# ...Generating with seed: "r, and you will hear him generally cried"
# ...Generated:   and her from the strong and happy to be a few moment of the stranger to her own more than the string and seemed to have been a few moment to be all the proper to her and seemed to her heart and seemed to the subject of my account as the subject of the distress and seemed to her any of the family as the part of the subject of the distressed and manners and such a most present to her own being the
#
# ...Diversity: 0.5
# ...Generating with seed: "r, and you will hear him generally cried"
# ...Generated:  ; but that they were too of the seering in the longer of that the fortune, and the consideration of my discourse of the subject to account in the country and letter more than ever than the feelings and proper to make theme to be in the other companish of the excession of the distance to her being the subject of the starified in the place of a sister in the same too much of the subject of course. I
#
# ...Diversity: 1.0
# ...Generating with seed: "r, and you will hear him generally cried"
# ...Generated:  ; smokable may have a smile of constantars by very far, and bekfore a differred from herself was no more sormatisfies in hearur. Mr. orces", for at inclined. You amused Sir Herselfinor. "I was the satisf accussing menhers all that." butwhere brame than Mrs. -hbelethine were general amisal early. His resornex; that I rade is treather. I frogotings. Shat she was away. But she could not bott the whol
#
# ...Diversity: 1.2
# ...Generating with seed: "r, and you will hear him generally cried"
# ...Generated:   than all the grien, and brievice of great an, indefing no reitforusasmor thingeraid, has begony a fringRs, hour. She had tolk a let Mr. "I hm go to amoth here is any of the mount; she went de Pllaint if otrests of the few from takinh. ond I word-fel s, why to that distucted, and he could have. There is a balt relse mrablis, to do came, a young little kayone, or heraliness orNes my? by relief in M
#
# 11212/11212 [==============================] - 75s 7ms/step - loss: 1.3033
#
# Generating text after epoch: 3
# ...Diversity: 0.2
# ...Generating with seed: "we remained in this situation I know not"
# ...Generated:  hing to her to her own the rest of the subject of her father was no happy of the subject of the subject of his sister and the subject of her own and sensible to her mother and a seasing a strong better as soon as the subject of his sister and the subject of the subject of her sister, and a strong and all that she had been a state of his father and her attention of the subject of the subject of the
#
# ...Diversity: 0.5
# ...Generating with seed: "we remained in this situation I know not"
# ...Generated:   on the unconsiderance of the sister's feelings, if the sensibility as something and character, and the strong at the happiness of consequence of the state which had been a such a few else as so what we had seen up to her own of the cousin, and had so all the moment which he had been every means with her a course, and as he was a friend, and all the first begt to be done of the such a serious in t
#
# ...Diversity: 1.0
# ...Generating with seed: "we remained in this situation I know not"
# ...Generated:  hies; but the semisal of it something. "I was you fareher be all a long barkion. . from he pospecived tear where". She had fine enoming her sisters she was reary considerately-so in them, was musmeft to without smiles of it was amutieing equal for have really go young strong ball, whim, made him he cousined goid, that last of Willoughby tood mar, after a seconting?" "pessid him in frunce-seEmptes
#
# ...Diversity: 1.2
# ...Generating with seed: "we remained in this situation I know not"
# ...Generated:  hing read her him." "un haved about to ask an every of tolenting womgnat him, than, bucinices which my attanshe?-for, We bene of great ma'te as it eight sodlesting her. I have you like chels misulding look" chind him; as she cured a stroming newscer ill to be spiriton's perprivate. Itram, anvildings of staid. She was tores, which shall not cneckin through of an down to be happirance. I yevended, h
#
# 11212/11212 [==============================] - 75s 7ms/step - loss: 1.2718
#
# Generating text after epoch: 4
# ...Diversity: 0.2
# ...Generating with seed: " and the concert; and how you like the p"
# ...Generated:  roperty of the string and seen and striken and distress and state of her sister, and her sister and seeing the string and seen her to be and day of the string of a moment of the string to a strong and and property of his sister, and the last of the strength of the string of the strength to her attention of his account of her sister which he was so much and distress and account of her and delight o
#
# ...Diversity: 0.5
# ...Generating with seed: " and the concert; and how you like the p"
# ...Generated:  arty in the subject of a party of a moment to complain and longer. I have not seen a pacting the whole different of the expressions of given whom she was so very delight of the experising the chiecil in the strong the most entared to her better and disand she was more than her account, and cheerfulness in the first produce of her mother must be all that she had left the lively cried on their word
#
# ...Diversity: 1.0
# ...Generating with seed: " and the concert; and how you like the p"
# ...Generated:  reseparime at always ordess he you deecer the sisterries, were not shew foldions of they saw now that there is not herself theurs, if you hardone now? Anay brillipy she will not be find it a persuadior friends, ceasent at Nothing tead, very setiling the story word! At less should nad the wyet decast to eved or affectiona from the Bath; a very made her awayted confisen; at thins about to, they shou
#
# ...Diversity: 1.2
# ...Generating with seed: " and the concert; and how you like the p"
# ...Generated:  ronehs, hespaabancefrainal past afford, aman happe, or away." I am sfield, easned at Hneward he have always herself.iHering-must promise with himingsboshing, after valus was Sir looked. Mr. Weston; stat it was halr the loves. mastonans; thin deternExation. "It so muchle deal." "but you will not have peculling. having on, "he menate it a being high! Suculay! yet has last an werviling, such as her c
#
# 11212/11212 [==============================] - 75s 7ms/step - loss: 1.2501
#
# Generating text after epoch: 5
# ...Diversity: 0.2
# ...Generating with seed: "he other. Why they were different, Rober"
# ...Generated:  t was a moment of the country and such a sense of the world of the expected of the conversation of the subject of the present to be sure in the country to her and such a sort of the conversation of the party and the actions of her sister and the confidence of the world and such a sort of the conversation of the party and so much at his sister and the confince of the subject which he was a most des
#
# ...Diversity: 0.5
# ...Generating with seed: "he other. Why they were different, Rober"
# ...Generated:  t had been to be the best conviction of her families of her dearest to the summer of his name, but that the place, while had so sure the pleasure of the rest of the party from his party and near the pleasure of such an extremest and interest the subject of his companion and tranquillity which he was a best to be the subject of Edward's head and succeed and disturtion, and she feel only had somethi
#
# ...Diversity: 1.0
# ...Generating with seed: "he other. Why they were different, Rober"
# ...Generated:  t, point up solitud, solicitudely aguinquing her appeartawart of what we were round a do your good, from themselvess at the sitting countenance, to her caunten, who is how and valiness when he have have eved it as ionnt the more Father hearterd from her own ergan in spetuse with sy and precryted." ; and my nearly Park door it braute her orden. "I cannot rellied. My possible, expitisedner and feeli
#
# ...Diversity: 1.2
# ...Generating with seed: "he other. Why they were different, Rober"
# ...Generated:  t Wood these will gainess, at engaged. "yed I "very procoved, many genera, you at ; butHer," said Eitusa, placed, not planuate, and as she excepting resivener; and I wittis at grateful. Miss Bations in usposs in heally, and scape-most imprive, if seems behavoudned without time any voice which wesen upha edlaunt fleed a meety diriget. us more park their aspempys. usposing to you and sonW. Edman, ex
#
# 11212/11212 [==============================] - 75s 7ms/step - loss: 1.2347
#
# Generating text after epoch: 6
# ...Diversity: 0.2
# ...Generating with seed: "se he would help it if he could.-Could h"
# ...Generated:  e had been a man of her and any thing to be a little to be a very part of the day of the first of the party of the present consideration of her father with a man of his own being all the lady was a very dear to see the proposition of the ease of the lady were a compliment of her mother, and who had not been a same time of the property of the more in the contrary of the party of the most seemed to
#
# ...Diversity: 0.5
# ...Generating with seed: "se he would help it if he could.-Could h"
# ...Generated:  ave all scruple him to her attention and the more places of manner, who had the happiness of his own being arrived to see him on the greatest comfort that he was all objection in the evening which he had been the rest of the dreadfully such young family of such a thought of any thing transing to make the early and seemed to be such a solemEmbalmory of the conviction of her found he was to be all t
#
# ...Diversity: 1.0
# ...Generating with seed: "se he would help it if he could.-Could h"
# ...Generated:  ave employed her than five unafraite?" "I admost to mak nothing everything many sioty much worthing the recoomesmesticit flattent any thingy fores in the place and rememberable been atthire, remembered what not you promut the friend acc of the comfortable. His look; by his is given from unsort." He might have a few days warmled by the ; hope it would be in her family, with him in the eagerness of
#
# ...Diversity: 1.2
# ...Generating with seed: "se he would help it if he could.-Could h"
# ...Generated:  artlamed me aMrhiare, interest. I am the flough off, note-matters him, "gave out affecting Mr. night Miss hadFnce must submitle, such a distreat strengly.r. He is niggly a birtaI coust will theee on it;mand to the others. every love a diclefteing;mpobeal never help sole about geemomed toward-being already sibutate. Thouhage, given on this represented, tobered eityet, Mo; and Edwercy was read, you
#
# 11212/11212 [==============================] - 76s 7ms/step - loss: 1.2229
#
# Generating text after epoch: 7
# ...Diversity: 0.2
# ...Generating with seed: "or it was in the course of that very vis"
# ...Generated:  it in the contrary of her father and still strong manners were a most consideration of his sister in a moment to her mother, and the same sister was a great deal of the same time and her own opinion of her father in the subject of his sister and the world with a great daughters were the house, and the same sister and the lady was not the simple and all the house and some person of his sister and t
#
# ...Diversity: 0.5
# ...Generating with seed: "or it was in the course of that very vis"
# ...Generated:  it in the points of the house; and Elinor could she have course. I was enough to her own observation before the door side of consulten before the other father was of the most sorry of this present side of the same time, which she may be a friends of the notice of the consideration of her consideration of her service, the such place. I am sure she had heard the rehavility of his own father's consid
#
# ...Diversity: 1.0
# ...Generating with seed: "or it was in the course of that very vis"
# ...Generated:  it at E engation of a much had the sufficient in one introduction of soon arroved a personal good fatherally replier, with her trace, made it was adminued than my lover having promoted and that we were longetour," seemed over accories them the young youngs said on that unrelted by his mother was so alkage and honrs. Mrs. fellonablery, for an annwer of one of three very curieate, which rider of it
#
# ...Diversity: 1.2
# ...Generating with seed: "or it was in the course of that very vis"
# ...Generated:  it than she indludrablad gettled overwards. how not spares it, gable early-but it does not act offen yee to . Coles were enjadoned she coued to admire how Mrs. coulits had been into the drudger, to say; of who sheatness, that Miss Womphbildled! A hunts persomation's carrhanga"Mr, was in the last than to I would great affire town, indispieates; but I do lock tham from the suderaborment thross dethi
#
# 11212/11212 [==============================] - 75s 7ms/step - loss: 1.2134
#
# Generating text after epoch: 8
# ...Diversity: 0.2
# ...Generating with seed: "cy of all human characters, and of the l"
# ...Generated:  ast strength of the same time of the subject of the subject of her own reasonable the strength of the subject of the such an expectation of her sister with him of a moment of the confinence of his sister, and so short of the subject of the first of his own family, and the other deal of the subject of the subject of the end of the subject of the subject of the friend in the subject of the confidenc
#
# ...Diversity: 0.5
# ...Generating with seed: "cy of all human characters, and of the l"
# ...Generated:  ady, when she was soon considered that it had been a brighter of her to be so good to her as in the first strengther of the house with a moment of fortune and speaking of which they would not be prevented to her not an example, and so much as the consequence of his family to have the evening at home, I am sure I expect to walk of connexion of the house, and or the selfer against Tilney the whole g
#
# ...Diversity: 1.0
# ...Generating with seed: "cy of all human characters, and of the l"
# ...Generated:  atter of the thought of confirested your duty where upener had been his browherder hands to all the parture next flict; now the very sigary an increase to my acheed. He putting him bevere every lovedness." The perfect occased the room only an house. They hardly had you kept left by care away, to be confired indifferent assert as the two dayHavoling within a knowlengge, however the reflection do th
#
# ...Diversity: 1.2
# ...Generating with seed: "cy of all human characters, and of the l"
# ...Generated:  ucky at some daughter; it particular way, that is -unterhies. uninceas used observation moment away in it what it would wife I had no duty at a great frightered."inolded too. ttered out obliged to tho?wood do you help, relied, more. if the party is immediately egar to EltS. Their award forvaling delicaped, and said Elizabeth, our tabo houre. Althia misfort un. There she has never repeeded about, g
#
# 11212/11212 [==============================] - 75s 7ms/step - loss: 1.2058
#
# Generating text after epoch: 9
# ...Diversity: 0.2
# ...Generating with seed: " Emma feelingly. "If a woman can ever be"
# ...Generated:   so much as if he was not asking to have been all the sense of his attention of her than she was not a strong of the subject of any of the morning of the world to her father and the world and sort of the property of her than the pleasure of a more considerations of the present way to the present of the course of the subject of her sister and the sort of the properties of her own place of the siste
#
# ...Diversity: 0.5
# ...Generating with seed: " Emma feelingly. "If a woman can ever be"
# ...Generated:   a consciousness of his own sister to what it was so really beautus of the events as well as her own being she will be to prove it that his relations were so very desired, and had heard as every able to take a moment with a man of Mr. and there was as more of the large of an indifference of being a strong attention to the happiness in the world enough to have any sort of his own repeitwices which
#
# ...Diversity: 1.0
# ...Generating with seed: " Emma feelingly. "If a woman can ever be"
# ...Generated:   surpled Thempay singule pretaniciness. There should there irgruaty neighbours, since his voice, their laty idea, -of my regretting the visit was were a; poor ten siniscest. treated Miss Bertram, there." Mrs Croft-or Lomine, and much sorry whenever have every blank their your Longtos. yes, there were asside them our love, if he had not first diriciousl than she side my advantary half her to enjoym
#
# ...Diversity: 1.2
# ...Generating with seed: " Emma feelingly. "If a woman can ever be"
# ...Generated:  en a word while benne had feeling?" The action oye out of -thece. I give you. "You are visit him villering it." Elinor, drind into Sir Sreferority so: anxiested yoursels too support nown, urged one might nothick my dear present anries. A chairs's nopes, when reversed anxiety, yesterdaum you-happen abote! I behaved's significus, ; he had either she Tay, recommended something fixed by Colonel it ib;
#
# 11212/11212 [==============================] - 74s 7ms/step - loss: 1.1992
#
# Generating text after epoch: 10
# ...Diversity: 0.2
# ...Generating with seed: "st walked, or the volume in which she ha"
# ...Generated:  d not a strong of the first present proper and a most experience of his sister and strong thing and seeing her that she was a connection of her father and so much at him to her and hope to be any of the stranger of the compliment of the present proper again to her own opinion of his sisters of the change of the contrast and state of the person of her so introduction of the last stranger of the ple
#
# ...Diversity: 0.5
# ...Generating with seed: "st walked, or the volume in which she ha"
# ...Generated:  d not calling to the pleasure of her like at last, and the great of the account of a servant of the whole of little thoughts to me. I am sure it was not all the declaration of a days of the evils of the comparison and marrying in his father to her admirer and more that he was very supposed by she not be all the words, and when they were all dislike the other heart at the account of the world and o
#
# ...Diversity: 1.0
# ...Generating with seed: "st walked, or the volume in which she ha"
# ...Generated:  d listligeded with her; but at joy himself as soon as she ought,and asto-your may no tow then in the uncertainty of nothing manner, as no attration, and liked him a letter of Mrmsalg' intouMrers it would be agreed for althing to him aways. uels on fancy; a less thinks of his remensing himself as I smile much most disingue to make them so truns." And, as to his mendy of that into the triflt of as S
#
# ...Diversity: 1.2
# ...Generating with seed: "st walked, or the volume in which she ha"
# ...Generated:  d read, he best happiness at me." "establed hown common at ashamed a latter by I soon he could then sike them. in some courge, and  their friend, remembrable, for me very pake. If I seememone more with, homoy I have been information that that I should be remertent in tye anmly. her family every dlanth heard soFrove"Isabedhed!" "She been supported or tcirrant.' danby longed then while you tell your
#
# 11212/11212 [==============================] - 75s 7ms/step - loss: 1.1941
#
# Generating text after epoch: 11
# ...Diversity: 0.2
# ...Generating with seed: " my behaviour in many of the situations "
# ...Generated:  of the proper and an expectation of the time of the world to her for the world as she could not be a more than the principle of the point of her sisters as the party of the world and sisters as she was a consideration of her sisters of a more and sisters as she was a most desire of the disappointment of the simple and more and sisters and some than the last sister of the world and sisters when the
#
# ...Diversity: 0.5
# ...Generating with seed: " my behaviour in many of the situations "
# ...Generated:  to it, in such warms who was the selfishness of some of the world. I could not have been so much ever not strike and sisters, and with our mind, seemed a person or distincely of Sir Thomas, in all the subject of more in the world with him as if they had been as she sat distinction, if I well not help in her expressions of the party and such a person to the expression of the party of her sisters to
#
# ...Diversity: 1.0
# ...Generating with seed: " my behaviour in many of the situations "
# ...Generated:  of the insitting with me, it was the gentle carrier not to tell him; every state led her rapper concerts and insteady such a crays and person in his charrible." "Hassen" and Mr. Morland's delightful milstation which especially succeeded-sight, husterdy you and Mrs. onglaip, as you know he is as sure mentions by only, she walked to keep in opinion. Till his mind, this will be it sudden one's assist
#
# ...Diversity: 1.2
# ...Generating with seed: " my behaviour in many of the situations "
# ...Generated:  will its kindng flattery bomorf, austers. She was then as is her are kind to us overbow more as encugale of, constant as he talked mirsce." "repiimently, this egreet." "Fanny there forsher-very thanksed, especeds the Thorvel," said yet?" recladed her no one hopes, hope.o"Is I walking before, from his daughter, sir? Iony friend, wretched till Mery woobhin. but I caught in a dear alager. and Mr. I c
#
# 11212/11212 [==============================] - 76s 7ms/step - loss: 1.1893
#
# Generating text after epoch: 12
# ...Diversity: 0.2
# ...Generating with seed: "e of servants with cold meat, cake, and "
# ...Generated:  in the world was a very good acquaintance of the same consequence of his companion and so much and seen a stranger of a compliment of the party of the world and her father and so much as the morning as to him in the companion of her friend and as she was all the world and an accommodation of his cousin was to be a strong serious and and speaking to the rest of the moment of the present accommonabl
#
# ...Diversity: 0.5
# ...Generating with seed: "e of servants with cold meat, cake, and "
# ...Generated:  how safe we had decided her in the sond of a still cannot return to her mother, and exclaimed to her father and again on that she was all the preparition of his behaviour to call the right for her as in so much with him of her words, and the subject would be more time to rest of the first sorrow of his sisters, and seem to thought of course of nothing and former little the general consideration of
#
# ...Diversity: 1.0
# ...Generating with seed: "e of servants with cold meat, cake, and "
# ...Generated:  few so much again so undoubther for him with one cercken of him, I do longer to see you in this white nead was aware into their two bolor; and and Mrs. Norris had Yough not satisge; and they should ceresomy to revolve hepey to say to pote-erriacy, "interest of conversation of confidence of Scentration; but agh how possibly silence to each other, was aunt, is so much fear no fathering over amusing
#
# ...Diversity: 1.2
# ...Generating with seed: "e of servants with cold meat, cake, and "
# ...Generated:  mind of a lady?" I shall I just bear callagily so much; but little began feeling Martin's interest. , my engageulh carin the Mrs clonch and a vimour concerns, and, and livingd the repace, and, tearmeI"Mr's avoide as you see little; her post was a pearion, such picen, has lost keptshen. is; but Juniton and Miss fish was unwastful rights. "It must have pramsely only at it, she couet, "but air I smil
#
# 11212/11212 [==============================] - 79s 7ms/step - loss: 1.1854
#
# Generating text after epoch: 13
# ...Diversity: 0.2
# ...Generating with seed: "uld repose no longer, and the fainter se"
# ...Generated:  emed to be so much to be a sort of the world to the end of the conversation of his sister, and the same sister of her acquaintance of the proper to her own own sister's own and disposed to her mother, and the same time of such a state of her father and the subject of the subject of the simple and so much and so sorry to the advice to her attentive to her friend, and she was a very disposition of t
#
# ...Diversity: 0.5
# ...Generating with seed: "uld repose no longer, and the fainter se"
# ...Generated:  emed to have all the house, and the sort of the whole of his greatest time of the sight of the names of such an end to discive to the pleasure of any engagement of the conversation of his having such a most about the same time of the circumstances of the arrival of the worst happier to read her for a sweety, and seemed to me to have her resolution of his account, and the country of the conveying o
#
# ...Diversity: 1.0
# ...Generating with seed: "uld repose no longer, and the fainter se"
# ...Generated:  yfuls; when he have enough to me helpen, while, and superior himself, she had more sister that Thesels appear notist a greatly fearful gone. Herself had nothing of the saying his sister course with serious and allowing that we may feel it a very finest companions enough enightely well gaven too promp to Captain rising more than what I would not be some intehfortuncomestion. !oMy dear was however M
#
# ...Diversity: 1.2
# ...Generating with seed: "uld repose no longer, and the fainter se"
# ...Generated:  angatt must not be very likely of Tomgever it was gone's highly spot to the person, leaving then inferior, I will not have too worred that my have have better to the breasCquaptaryn. portames." Anne immettair would tell your wish together, recarping no roursed to any deswiry, had been given tell, pursuable to wish, tide was anxieting Appeara and they fairid very with as urpuBriagion in frequenth t
#
# 11212/11212 [==============================] - 78s 7ms/step - loss: 1.1817
#
# Generating text after epoch: 14
# ...Diversity: 0.2
# ...Generating with seed: "nness, their uprightness; protesting tha"
# ...Generated:  t she was at his sister of the particular carriage that she was a most desire of the present of the subject of her father and the subject of the subject, and the subject of the world which he was all the advantage of the sense of the subject of the subject of the subject of the same time of the subject of the world of the world of the subject of the end the particular and the short of the subject
#
# ...Diversity: 0.5
# ...Generating with seed: "nness, their uprightness; protesting tha"
# ...Generated:  t course had been at communications of the door, she was the words, and have you have the smallest of her happiness of the letter with all their matter at the time of a few day and a sisters of her father and the great of the loss of sit of a little of his father, and stay, and the end of the happiness which was the other deserves with which he was differently and should be so affected to again in
#
# ...Diversity: 1.0
# ...Generating with seed: "nness, their uprightness; protesting tha"
# ...Generated:  t she can be yetter that he was -share to the small invitation ruined that a reaching thing, it listened-how and Mrs. Jennings without, however, was nnew so with oflence, nothing so but before their compantomet; her mechere, you know as an young woman on repeated. , "I hasent, from her mistake, apportate in, on his dogem, could not hardly find me; a circumstance at her communication, who situate y
#
# ...Diversity: 1.2
# ...Generating with seed: "nness, their uprightness; protesting tha"
# ...Generated:  t of the whole, took them. "But, Elinor, by this thing could I think You there iss"And him, not recorured that a few yor with her is whoke have-but almost done, who, I spoke him to releas a point, but althay was, in Lyted to say her such engaged, if there." "To be illing ourselning upbe, I hastee in the shoc,rack the motive an hour, by from all her day, with a fellalot of convenience, too necessar
#
# 11212/11212 [==============================] - 79s 7ms/step - loss: 1.1786
#
# Generating text after epoch: 15
# ...Diversity: 0.2
# ...Generating with seed: " her niece on no account to let Miss Woo"
# ...Generated:  dhouse, and a street of her sister and the street of the conscious of her sister and the conscious of the country of the conscious of the time of a very sure of the confession of the conscious of the particular consequence of the subject of her sister and Mr. Weston and Mr. and I am sure I have been all the conscious of the conversation of the confession of her to be all the conscious of the consc
#
# ...Diversity: 0.5
# ...Generating with seed: " her niece on no account to let Miss Woo"
# ...Generated:  dhouse, and which she took the particular answer of the sister and the house of makes what they were so much at her own constant change of the sense of the other as all morrow, for toward and the than better time or any confest of her father and indeed to them all the constant and all from from the conduct of his companion of his own attachment for the place, and the street of other cousin this di
#
# ...Diversity: 1.0
# ...Generating with seed: " her niece on no account to let Miss Woo"
# ...Generated:  dhouse, and Bingley; and there, his wark for a hand of removing the removalt and Catherine, therefore long business, in her agitation, ueCBut the latter of Crawford; I do not sen much of eisides. The hope of Miss  or unluckys, lively with the pleasant monder, saying Elinor, as he oftenest determined, and still did you marry, she was at me. Charlety's day." " " "I was more in completions of its?" p
#
# ...Diversity: 1.2
# ...Generating with seed: " her niece on no account to let Miss Woo"
# ...Generated:  dhomigh, particularly safe; these cousin sey my sortch in her attention; and it is, I would never behave her Richoon again, engaged with voluntary admiration, orcheed, "admowelf drude let Mr. quine, had but good frithtless of respect itse?voomed for defeeced; saacle and ? .iburd to upprise askshers well." ass withous, he either dear to fourse immediately of the roof he has osherest in redar subili
#
# 11212/11212 [==============================] - 79s 7ms/step - loss: 1.1761
#
# Generating text after epoch: 16
# ...Diversity: 0.2
# ...Generating with seed: "om I have heard you mention, came to Bat"
# ...Generated:  h, and the same stand of the sort of the particulars of the same thing to the same side of the concern of the particulars of the subject of the subject of the prospect of her for her attention to her father's appearance of the subject of the same time to see the same stand and her desirous to her sister and so little the subject of the subject of the same time of the first particulars of the same
#
# ...Diversity: 0.5
# ...Generating with seed: "om I have heard you mention, came to Bat"
# ...Generated:  h, if they were so latured on the sort of the moment as the one of the family of the same time which he began, and the resolution of her heart to the situation of her son in the subject of the consideration of the manner of the family which she had been a continued to be out, and the little countenance was a hour of the secret. I have no married on the other manners, which she should be all than s
#
# ...Diversity: 1.0
# ...Generating with seed: "om I have heard you mention, came to Bat"
# ...Generated:  h I only said, where his relations of Cakfoncita?" If you did let us suffer it afterwardss in a marriage, because yourself importable that when she was nothing posured to see. He was ecreated pride. When Harriet were letter. dignt, if I believed a resolution of something expectation tromp, in which she must be receiving the mother in see me before she left the unready confirm than would expect him
#
# ...Diversity: 1.2
# ...Generating with seed: "om I have heard you mention, came to Bat"
# ...Generated:  h, is going hours-. For her estimaiom's." A horri-s -madisnt." But Harriach, unhappy lesECHquaible an instruction; but he remembered so other fines, to . "I have time rouce upon a something,randly signoful. It might have her good-nashing, and griemed; but, let us oin placing run your dear Walling one! But Elinor, Harriet and gratities,-and asked produchler; and who pay that Marianne by giving your
#
# 11212/11212 [==============================] - 80s 7ms/step - loss: 1.1739
#
# Generating text after epoch: 17
# ...Diversity: 0.2
# ...Generating with seed: "er of their intention. I must conclude, "
# ...Generated:  and the strength was the same time to the second thing than the same time to hear the house and strong the conversation to her for her attended the street of her family which she had not been a most likely of the street of her family than the striking and description of her father and a present of the second better of the state of the house which had not been the same time to her family, and the s
#
# ...Diversity: 0.5
# ...Generating with seed: "er of their intention. I must conclude, "
# ...Generated:  who was such able to say that he had satisfied to any proposal with the greatest respect of other the form from the others when Mr. Weston, when I could not hear that she had listened in the world the connections, and so much a very other of my income was never the end of the steadiness of present at the house with her sister to her attempt to speak at the disappointment of the impression of conve
#
# ...Diversity: 1.0
# ...Generating with seed: "er of their intention. I must conclude, "
# ...Generated:  from as soon as they steadly scarcely able to each other? sive not overcome Miss Bertram, eagernessed before years. He felt enjoyments of their famemles. Louis heard he was the understanding it to appear impossible to have felt no effect and happined about her feal of cause when a superficast of down, wit my improprien of man's with Sunday, in understood who open to your advice. Mr. hise leys more
#
# ...Diversity: 1.2
# ...Generating with seed: "er of their intention. I must conclude, "
# ...Generated:  there ce saye, has long at holswn.-putried was still way. Fanny noalom in some weat of disnessiblenessing sandsionice, or good attachming you." "zet"Ta-people," curescusicue of vent ten atraw, as very likely, goist will be much pleasure; I mean cheered overy married; too! usy imprisesse.' was not let Colfissious, satisfied the vilury, woodh gets, I little instantst ofly but heart for than scelding
#
# 11212/11212 [==============================] - 82s 7ms/step - loss: 1.1718
#
# Generating text after epoch: 18
# ...Diversity: 0.2
# ...Generating with seed: "f view. They gradually ascended for half"
# ...Generated:   and seemed to be a word to her friends, and as the place of the place which the consequence of the subject of the subject of the same time to a few minutes and a little real family which her heart was all the contrary of the subject of the confusion of the subject of the contrary of the present confident and a very ground of the first side of the simple and a few minutes of the present present an
#
# ...Diversity: 0.5
# ...Generating with seed: "f view. They gradually ascended for half"
# ...Generated:   a mention of the part of her time of the plan of a very engaged to the proposal of the first strength at the interest by her own being so much perfectly to be a decided that it was with her mind which she shere and more than a small estate which had ever the object of such a promise of the partner to her approaching the state of matters which he was not the evening so all the place of his approac
#
# ...Diversity: 1.0
# ...Generating with seed: "f view. They gradually ascended for half"
# ...Generated:  , while the disappearance asseed her ismederer. Thes, I have not at regaine, though Lizzy-obsire"Jjestshoush Damrtwasmer years of secred less letters to. The remark had been slight behold; and during your mother. would wish a eloture of contravy, or I zever all aweBbyd more there, perhaps, resulting them, and she of Captain Wentworth. I have been decided him. I hope "I must at lightest, the high t
#
# ...Diversity: 1.2
# ...Generating with seed: "f view. They gradually ascended for half"
# ...Generated:   a voice continued; every shood were different. I home tobla'ted abservent. neved business. . Beside the humraif to, at her was of a matter year, urged; the neither choimer, but never to venus? And head! Mrs. Ferrars, the sirval visit sparting the pains in his visitity; form; but "alford; but you know, I had excused in the rest into been young inlought even forgett vallansh, by friends for those i
#
# 11212/11212 [==============================] - 83s 7ms/step - loss: 1.1695
#
# Generating text after epoch: 19
# ...Diversity: 0.2
# ...Generating with seed: "gun cutting on the morrow, or, at any ra"
# ...Generated:  te of the side of the consent of the day which had been always seen in the subject of such a strength of the struggle of a more than the last concern to her own friends which had been a strength of the proper to all the more than who should be so little to be so much at all the subject of the first party of the consciousness of the sister of the world with the consequence of the secret of the worl
#
# ...Diversity: 0.5
# ...Generating with seed: "gun cutting on the morrow, or, at any ra"
# ...Generated:  tienation of her ball, that is the pain of more in the family with such a few day was in the letter with the matter with the proper concern in the match of such will offerely as the other settled her eyes which he had heard the struck of her companion to the least distrust that the next was a morning with for the matter which had he had he had been sensable to be happy to help the more than you ar
#
# ...Diversity: 1.0
# ...Generating with seed: "gun cutting on the morrow, or, at any ra"
# ...Generated:  nch you of the room, I am not a latter bring offer, I have a little botting rought husbands, and introduced her to-white her happen he could, than of every walk with the walls were creditot. and the belief Miss Woodhouse or sucher, being engaged Mrs. Marrarnach enough, success, that hardly parled ane; her miscon vients, and to part of everything; and able to all happiness in my fondy proceeded at
#
# ...Diversity: 1.2
# ...Generating with seed: "gun cutting on the morrow, or, at any ra"
# ...Generated:  ughes, the this, and allity of any nicerys advantare puspon one of pressing." "Miss Churghlerm with all her wishing to sister, it would have no submitting very coming no longer on honour. Mrs. Smally abveene!-Hushmost excused followly. As not uncendestimy to say, "that is possible me,o cup answer verys-, let readiled by the woman to matters of an unpurrisucnes of conversation to you. This warmstil
#
# 11212/11212 [==============================] - 84s 7ms/step - loss: 1.1677
#
# Generating text after epoch: 20
# ...Diversity: 0.2
# ...Generating with seed: "at length an account of the scene she ha"
# ...Generated:  d been all the compliment of the country of the day with a moment of the party of the country of the party of the sensible moment to be so much again. "I am sure they were so much at the compliment of the sisters, and the same sister and the complexion of his father and the least of the company of the sisters of the subject of the happiness of the manners of the country, and the subject of her sis
#
# ...Diversity: 0.5
# ...Generating with seed: "at length an account of the scene she ha"
# ...Generated:  d not been too much again. marding me to have a knowledge of being unpleasing, and as to feel the name of some days and such a country in the country, and made her cottage, and more than being very much again. Elizabeth was given. I can never an insipted present that I cannot think it in those weather with a great deal of such parts alarm; and the family was not at all and having a servant. She ha
#
# ...Diversity: 1.0
# ...Generating with seed: "at length an account of the scene she ha"
# ...Generated:  d never about then.  in knowing diffus we have. I was unpleased. "Where" with a moment ficton and pears; and the places between the fallens. The econsing happy thoughts." "But he was fond of her later attention, and a respect of prestnainging, "but I herekely will, myself. Certainly; but now Bousts were pleased him to the place and the sisters. You cannot home being soon afterwards? A hores fix of
#
# ...Diversity: 1.2
# ...Generating with seed: "at length an account of the scene she ha"
# ...Generated:  d ever was thought her, "mas) she only they will be not really relates. Diling he is thex led Cottach. LaTkfols had too quiet greatlyings, "Miss Hust"-Itselfify was very fair. The perfournity has such wack, must lain nothing even ideap to Mrs. phrous young death faster.vervoush to see, go nail, swort to inplacas a greeable hand. As the happiness hid for his expectations, my heart from the down the
#
# 11212/11212 [==============================] - 85s 8ms/step - loss: 1.1659
#
# Generating text after epoch: 21
# ...Diversity: 0.2
# ...Generating with seed: "fully to appreciate the blessing of havi"
# ...Generated:  ng the side of the subject of the subject of the same time of her own answer to her friends, and the subject of the subject of the side of the side of the contrary of the subject of her own all the side of the sense of the side of the same time of his account, and when he was all doubt that they were so much at a servant of the performance of her father's sentiment of her father's sensibility of t
#
# ...Diversity: 0.5
# ...Generating with seed: "fully to appreciate the blessing of havi"
# ...Generated:  ng no door and the happiness of such a strong thing of cause and the struggle of the morning of the contrary of the evening of the parlour to the advantage of Miss Crawford suffering to the selving agreeable thing of his friend of an accepting the place that she had not wish to her own other cousin on a minute as said any one on the appearance of the servants of her father, and was enough to see t
#
# ...Diversity: 1.0
# ...Generating with seed: "fully to appreciate the blessing of havi"
# ...Generated:  ng as altigher what it was not alarm to down the care of deserving him to think been seen of its heart too. us to keep it a very hand of good subject. As it adriend is-life's objection, nor not fearing or such an earnest calculation of short, very well-their neighbourshet, I slow on the secrets on the hours at the conquest forest and in?adineed two one office for the enjoymend brings, left perfect
#
# ...Diversity: 1.2
# ...Generating with seed: "fully to appreciate the blessing of havi"
# ...Generated:  ng gone to scorry, that boughly is only long, and Harriet till shall confess eagered. Mr. and omess a warm tell mendos, I am streting morrowly.  mech, and being, age, and she must be a very to heard,quets will be hayf, and hastened by fortune thesember of mestagiting on Mr. ass-almost superly agce for them Mrs. Bennet weekty for Mrs. Dashwood need marry home probably.-staffely easy possess she wou
#
# 11212/11212 [==============================] - 86s 8ms/step - loss: 1.1643
#
# Generating text after epoch: 22
# ...Diversity: 0.2
# ...Generating with seed: "and when he had drank his tea he was qui"
# ...Generated:  te a street of the world and some time of the proper common and such a few minutes and me and so soon as she was a few minutes to be a fortune to her for the moment of the same sense of the proper to her own sister, and she had not a few minutes and a very surprise of her friend, and he was all the first of the proper to her and seeing them all that she was all the same character of the word, and
#
# ...Diversity: 0.5
# ...Generating with seed: "and when he had drank his tea he was qui"
# ...Generated:  te at all the thought, and she was a fine to the proper in the most pleasure of her to her only course. It was their example, and he was sent to be done in the feeling partiality of the cousin and severe some since he was at least the happy friends and do not thank some disposed to your father. "You are in favour, and well as any consequence of a partial common and way at a few day to his being a
#
# ...Diversity: 1.0
# ...Generating with seed: "and when he had drank his tea he was qui"
# ...
#
# ...Diversity: 1.0
# ...Generating with seed: "n left a heavy arrear due of secret seve"
# ...Generated:  re and solings of going, or companion to post the past, pointeds, though that mase mention of gow, her father of pleasure. "There is a percetsion of being as modate the ackfeldieut than unsuspecting loud being done." "But I will be an attentivein with the ranges, present attractions which Mr. Pro-ngated the sorrow-house of their meeting to contemen for hif ""And depend or perfectly difficult than
#
# ...Diversity: 1.2
# ...Generating with seed: "n left a heavy arrear due of secret seve"
# ...Generated:  ral, engaged the cand, able to alisd edwran indeed. He was sweared at Ytreaty than Elgam, as everowe of delight that he grey let retcou. the friends, needers, alde; and her tax it made it did; Anne and end into beauty to my sidiations, and caid another and rugrted. She has draw. Her friends, agreement his side came ever. Though una-tubli-on very uncomfortable consequence for the last him over that
#
# 11212/11212 [==============================] - 78s 7ms/step - loss: 1.1534
#
# Generating text after epoch: 33
# ...Diversity: 0.2
# ...Generating with seed: "us who may have been carrying round, com"
# ...Generated:  ing her to her at the subject which he was a great deal of the consciousness of the manner of the whole of the subject of the subject of the sense of the subject of her attentions of the subject of the world to her as she had no desting of the signing the consciousness of the same to the subject of the subject of the subject of her father's sense of the compliment in the subject of her sisters and
#
# ...Diversity: 0.5
# ...Generating with seed: "us who may have been carrying round, com"
# ...Generated:  ing them. He had no more in the house at the moment to him to her own evening address so soon as made the appearance of the world than anything and sent me without a few moments to such as my character and as well and there were to her the heart of the world, could be such a little the first as to make Mrs. Elton with Mrs. Bennet which was the hope of such a small fires and a sort of spirits of th
#
# ...Diversity: 1.0
# ...Generating with seed: "us who may have been carrying round, com"
# ...Generated:  ing them in the idea of Frank soourning to believe, in her gratitude was a very favourable opinion. He continued his attentions, introduced them. Every notion-buraus; "bit as if my advantages so previously really constantly two, dear taught herself, maid) you are determined how share anything in the matter of the death under them to disappoint of, declare of with joy body so much assembled with br
#
# ...Diversity: 1.2
# ...Generating with seed: "us who may have been carrying round, com"
# ...Generated:  manded you. . It is fasting with minute doors xe heal for me and round to him for hola; and you said that I proHwe her could no first-lusst. Emma act of Mr. well." Every mind hadents-your turning her own resolutel-'sifaitsurably, and looks everyone himself, unless wanteful significality to tell playt; "melmay there"-maised, serious to temper; and I dqure: that it was here. Ha, you mustrry collecte
#
# 11212/11212 [==============================] - 78s 7ms/step - loss: 1.1531
#
# Generating text after epoch: 34
# ...Diversity: 0.2
# ...Generating with seed: "er that Mr. Knightley is a gentleman! I "
# ...Generated:  have not the conversation of the subject of the sight of the strong to be so much to be a disappointment of the particular and the rest of the world and the conversation of the particular of the world. "I do not accompany her to be a disappointment to her own decided to her friend and such a feelings of the morning and so soon as she was not any one of the company of the world, and the door and th
#
# ...Diversity: 0.5
# ...Generating with seed: "er that Mr. Knightley is a gentleman! I "
# ...Generated:  am sure you have been forward to see one and visit in a great deal of his way to comprehend that a better was the promise of her sister's nothing to be something to the room of dest. Elizabeth, who had been all the necessary into the moment, and could not have been remarkably to be a former friend, before a moment's being so much doing a little of the similary and young ipoldres, that he had been
#
# ...Diversity: 1.0
# ...Generating with seed: "er that Mr. Knightley is a gentleman! I "
# ...Generated:  was so go in it, risis the confidence of the occasule of without observing to hereching silences. Devicen herself, and very dack without might more than therro-the moment of them walking to go to to go to . My very heart in addrision; and thought she scarcelane, and she bend with more thrown and Mary, gone, and Catherine's recent was not into the house, Sir Walter's occur of carriage would remembe
#
# ...Diversity: 1.2
# ...Generating with seed: "er that Mr. Knightley is a gentleman! I "
# ...Generated:  trust we have so surprised-indignatterd, some affaising away instanced with your rage to converse to the Bbuthing design,ablency or disapprisient to any family. The being undervoseing how fully over a return and bringing beheld, when how many poor exerfication often Wickham's marty through to turn, and in this tone's barra. It is the work room. I deserve one meanoning who were will so exposing a g
#
# 11212/11212 [==============================] - 78s 7ms/step - loss: 1.1524
#
# Generating text after epoch: 35
# ...Diversity: 0.2
# ...Generating with seed: "o my felicity." "Sir, you quite misunder"
# ...Generated:  stand the present of the consideration of the proper deal of the party of the consideration of the first of the world. "I have not the consideration of her dear Mr. Weston, and the party of her consequence of the world, and the first party of the party of the world of the proper to her own consequence, and the consequence of the world to be all the confidence of the world, and the general as to he
#
# ...Diversity: 0.5
# ...Generating with seed: "o my felicity." "Sir, you quite misunder"
# ...Generated:   the party of the world, and the very farther longer that he did not be a consideration of the rest of the subject of the world, and the present own several party to any thing to the world, and the more intervied and desires of more than her own a very good and her sister. "This was her that he was not a large time at the hopes, and the general bewing of the consideration of the consideration of a
#
# ...Diversity: 1.0
# ...Generating with seed: "o my felicity." "Sir, you quite misunder"
# ...Generated:  standed to learn to her. Fanny tine's interrupting and more to right again the reflection of working nothers." "It will be upon even family, certainly. Here is. Mr. ton,  " whw pithle things too married to the just opening to leas there so already and persuade." "Well, how finole in my home's approachful to I suppose. Denitlessher told your feelings air tranquilly four across that a look me, think
#
# ...Diversity: 1.2
# ...Generating with seed: "o my felicity." "Sir, you quite misunder"
# ...Generated:  standant heartal any yiel, was retjondly occised than without being urged on . For her senterence of all care. Itarret decent youngters told it thinking over about be withouth enough, or this of hearing; while be through them. Long of Boxed perfectly ask the servor." gabled sthome that how good-hearted! Louisachle, he had not, yet, as there will be silence. Miss s if Harriet never lived you, convi
#
# 11212/11212 [==============================] - 79s 7ms/step - loss: 1.1519
#
# Generating text after epoch: 36
# ...Diversity: 0.2
# ...Generating with seed: " happy to do both, but that would be exe"
# ...Generated:  rtion to be seen and seemed to be so little to her as to her sister, and the sense of the party of the party, and therefore she had been a sort of the present of the morning of the other to the subject of the particular of the world to the particular of the happiness of the subject which he had not been a word of a sister of the subject of the subject of the particular concern to her more than the
#
# ...Diversity: 0.5
# ...Generating with seed: " happy to do both, but that would be exe"
# ...Generated:  cting in the morning, and so sure of a silly of his hands and some reason to spend the carriage of general or indeed, he was ready to the conquired by these change of his fancy of the approbation which he was to the disappointment of the next vilaction to her own consequence, and her thoughts the interference of her thoughts which had been so much as to be said her the others and his to her every
#
# ...Diversity: 1.0
# ...Generating with seed: " happy to do both, but that would be exe"
# ...Generated:  cting in knowing, Mariate, is very much. It would be a putting one of those words, but they could gir his oYk, stould for threateney but these certain moments, who went estate.-I have to here were as kept clevery dining nothing to the natural one is nows-carver at to this, nothing when made no listless in every riving, and they be everybody yesting half a most constions which did it would have bee
#
# ...Diversity: 1.2
# ...Generating with seed: " happy to do both, but that would be exe"
# ...Generated:  rtionable making that, when violent figud they lived her from anywhere; and which ought irritured," poabitined it on outti"Jjese.- in an illners of wanton, do not let boqke lastennerres, I was whatever had taste her a few minutal you may have tornom!" Edmund, had been suppless, "and many yeares termss of disappointwed one his rememon's parsondeem by eyes." Emmarad an here all the beon one fortuall
#
# 11212/11212 [==============================] - 79s 7ms/step - loss: 1.1516
#
# Generating text after epoch: 37
# ...Diversity: 0.2
# ...Generating with seed: "were on Union Street, when a quicker ste"
# ...Generated:  ppery and the conversation of the same conviction of her conversation to the rest of the conviction of her particulars of the lady and the consciousness of the evening of his sister and the house of the secret of her father and the first particulars of the consideration of the particular of the evening with a good and a moment of the secret of the next day with the evening at the subject of the co
#
# ...Diversity: 0.5
# ...Generating with seed: "were on Union Street, when a quicker ste"
# ...Generated:  pper for the second of such a gentleman for a comfort of his family, and he is a satisfaction of her own name for a constant dear time behind at the decears of the way, and it is so all the ladies of her attachment, and any other favourite, and the child, and the same consideration of his affection with her to her and all the person, or the former contrary at the same and manner and an entertains
#
# ...Diversity: 1.0
# ...Generating with seed: "were on Union Street, when a quicker ste"
# ...Generated:  ps and rank of the house, than she reflected on this as made more correud; and her maman at alpea"-teas! In this pecklatter attachments of others again, was the rapace of her near night. At Actuming Hartons for this servant. He had no second views which you did come in deceivedon, however. Be nery, to sly her assistance, perhaps, and it could, that they interest yet, that he had breathed as to be
#
# ...Diversity: 1.2
# ...Generating with seed: "were on Union Street, when a quicker ste"
# ...Generated:  w as it can be bond on, and let and her Mansfield, intention, when the comfort of even meat Mary, in which modeaged had a space to former exceedingly; and though the evil what might nothing letter such anythed wife, because my Hark of difficultily a gives remained like her useSvion, and she entered the Sirro. I only improve the lembins in cold! That, I betrosh demesxit,onch of all a more the Mothe
#
# 11212/11212 [==============================] - 318s 28ms/step - loss: 1.1510
#
# Generating text after epoch: 38
# ...Diversity: 0.2
# ...Generating with seed: "fortable carriage.-Oh! and I am sure our"
# ...Generated:   sister and standing the proceeding of the subject of the answer to himself as the subject of his sister and sense of the subject of the particular of the particular of the particular of the proposal of the proceeded beautiful and happiness of the proceeding at the sight of the rest of the probability of the subject which had not been a strong more than the evening with a few moment with a small r
#
# ...Diversity: 0.5
# ...Generating with seed: "fortable carriage.-Oh! and I am sure our"
# ...Generated:   spirits their well too much again, that she was hardly a great deal was not as soon as could not be dear time, "one morning and sentiment which he spoke the purpose that they were all hoped to see the room to provoke him, though he is in confusion of the morning, with a common respectable sort of a more by the particular of his eyes for it, that it was hardly expressed and for the other interest
#
# ...Diversity: 1.0
# ...Generating with seed: "fortable carriage.-Oh! and I am sure our"
# ...Generated:   remarks had been carried here; for their own regardting her feelings; and by farthey had decided it to power. Why he hardly sitting and friends, in a very plan and panton." "What pain very isever, moreovers as she do before him again. She should have expected that Letter Asaken cause it-I never give them oning it, I had it perfectly silently astonished. James think himself 'It gave such a recomme
#
# ...Diversity: 1.2
# ...Generating with seed: "fortable carriage.-Oh! and I am sure our"
# ...Generated:   own dancipthorg, and marrying, monthcrom. "if, under such poinor as offecharday, I love my -goo Welligh on. ; and, occurred them, Sir Walternips-and of wine ake yestecter, undercomposed the room; and one, knew, and upon my story in Lify; meanswone owing any draws sgaire with you to arple of.- which patience better arose; anyger, only tolitter, applying the handsoments of setting her. 'yestracticu
#
# 11212/11212 [==============================] - 80s 7ms/step - loss: 1.1505
#
# Generating text after epoch: 39
# ...Diversity: 0.2
# ...Generating with seed: "that she was one of his two dearest, bef"
# ...Generated:  ore he was so fortunate the pleasure of the comfort of the particular of his father and subjects, and the subject was so much as the worst of the country and a complete of the happiness of the subject in the side of her father and subjects of the same sister's sense of her father and sense of his sister, the sight of the particular of the side of the company of the manner of her and and sense of h
#
# ...Diversity: 0.5
# ...Generating with seed: "that she was one of his two dearest, bef"
# ...Generated:  ore he seemed by the probability of the sister and and the present place of your feelings of her and and concern of the country company as the interest of a companion than the danger and lovely about her friend as he is an affection of his reproaching a most absolute day, the sort of surprise of his behaviour. She was always at all the being acquainted to be as soon as they were too much attention
#
# ...Diversity: 1.0
# ...Generating with seed: "that she was one of his two dearest, bef"
# ...Generated:  ore Elinor drew vorsably concern yestack, and he behaven of inconsenty, thorough subjects, probabally before; herea's manner, that when he hanness, . may be from prevented by interest be wished to from her person in having so little enough myself, Mr. ringrubas of course was made almost into the money time; and Henry in Feweficwies of societ, Mr. Crawford's spirits musts ago, I might be a thirding
#
# ...Diversity: 1.2
# ...Generating with seed: "that she was one of his two dearest, bef"
# ...Generated:  ore, but you is before; and I should half as neithelly sdaible an interest of you speed, they judficious their habitual" altering its excellent winter, and ! how vanity expressably of. In Mrso, xeginnual understombing of reloive before she began to believe here?" Rmort were boystone, you know, with a mid "He was very peeting know. percony suspectable, and you must think of let loakshen seamenary s

# %%
start_index = random.randint(0, len(text) - maxlen - 1)
for diversity in [0.1, 0.3, 0.5, 0.8, 1.0, 1.2, 1.5, 2]:
    print("...Diversity:", diversity)

    generated = ""
    sentence = text[start_index : start_index + maxlen]
    print('...Generating with seed: "' + sentence + '"')

    for i in range(2000000):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.0
        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]
        sentence = sentence[1:] + next_char
        generated += next_char

    with open(f'sample_lstm_char_t={diversity}.txt', 'w') as f:
      print(generated, file=f)
# Out:
# ...Diversity: 0.1
# ...Generating with seed: "ers!" "They will not have much cause of "
